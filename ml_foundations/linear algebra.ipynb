# %%
# solar panel generates 1kj/day on 1 april
# generates 4kj/day on 1 May + 30 days

# what day is it when the MII design has generated as much total energy as MI design
# e = 1t
# e = 4(t-30)
# 4(t-30) = 1t
# 4t - 120 = t
# 4t - t = 120
# 3t = 120
# t = 40 = May 10th

# how much total energy would be generated by that day?
# e = 1t = 1(40) = 40kJ
# e = 4(t-30) = 4t - 120
# e = 4(40) - 120
# e = 160 - 120
# e = 40 kJ
# = 80kJ

# %% [markdown]
# ##### tensors
